# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %% [markdown]
# ### 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異

# %%
import requests
import json

r = requests.get('https://api.github.com/events')

# r.text 為字串物件，此外\n等特殊符號都會包含在內。
r.text
#print(type(r.text))
# json.loads 為list物件，排列完整可讀性高
#json.loads(r.text)
#print(type(json.loads(r.text)))
# Out:
# '[{"id":"11106896313","type":"PushEvent","actor":{"id":39325611,"login":"etEthiopia","display_login":"etEthiopia","gravatar_id":"","url":"https://api.github.com/users/etEthiopia","avatar_url":"https://avatars.githubusercontent.com/u/39325611?"},"repo":{"id":228615003,"name":"etEthiopia/DictionaryRMI","url":"https://api.github.com/repos/etEthiopia/DictionaryRMI"},"payload":{"push_id":4406931892,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"580e8ef7060ba62479958ea71deb52fb2bc54c5b","before":"2e850051c91c8121bee1e014b142fb453ca825f2","commits":[{"sha":"580e8ef7060ba62479958ea71deb52fb2bc54c5b","author":{"email":"daginegussu@gmail.com","name":"etEthiopia"},"message":"some files in","distinct":true,"url":"https://api.github.com/repos/etEthiopia/DictionaryRMI/commits/580e8ef7060ba62479958ea71deb52fb2bc54c5b"}]},"public":true,"created_at":"2019-12-17T12:56:16Z"},{"id":"11106896307","type":"PushEvent","actor":{"id":294849,"login":"miguno","display_login":"miguno","gravatar_id":"","url":"https://api.github.com/users/miguno","avatar_url":"https://avatars.githubusercontent.com/u/294849?"},"repo":{"id":228616456,"name":"miguno/borg","url":"https://api.github.com/repos/miguno/borg"},"payload":{"push_id":4406931883,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"cc2f5a22b0fe00cd6fe42fdc4906740446b9b5cc","before":"5739602a110a24bdfe2fa56b4cf09d6634b44b33","commits":[{"sha":"cc2f5a22b0fe00cd6fe42fdc4906740446b9b5cc","author":{"email":"michael@confluent.io","name":"Michael G. Noll"},"message":"Document how to test exclusion patterns without performing an actual backup","distinct":true,"url":"https://api.github.com/repos/miguno/borg/commits/cc2f5a22b0fe00cd6fe42fdc4906740446b9b5cc"}]},"public":true,"created_at":"2019-12-17T12:56:16Z"},{"id":"11106896306","type":"IssueCommentEvent","actor":{"id":6804901,"login":"mvdbeek","display_login":"mvdbeek","gravatar_id":"","url":"https://api.github.com/users/mvdbeek","avatar_url":"https://avatars.githubusercontent.com/u/6804901?"},"repo":{"id":31211061,"name":"galaxyproject/galaxy","url":"https://api.github.com/repos/galaxyproject/galaxy"},"payload":{"action":"created","issue":{"url":"https://api.github.com/repos/galaxyproject/galaxy/issues/6853","repository_url":"https://api.github.com/repos/galaxyproject/galaxy","labels_url":"https://api.github.com/repos/galaxyproject/galaxy/issues/6853/labels{/name}","comments_url":"https://api.github.com/repos/galaxyproject/galaxy/issues/6853/comments","events_url":"https://api.github.com/repos/galaxyproject/galaxy/issues/6853/events","html_url":"https://github.com/galaxyproject/galaxy/issues/6853","id":369157352,"node_id":"MDU6SXNzdWUzNjkxNTczNTI=","number":6853,"title":"Masthead does not refresh after new account creation","user":{"login":"martenson","id":1814954,"node_id":"MDQ6VXNlcjE4MTQ5NTQ=","avatar_url":"https://avatars2.githubusercontent.com/u/1814954?v=4","gravatar_id":"","url":"https://api.github.com/users/martenson","html_url":"https://github.com/martenson","followers_url":"https://api.github.com/users/martenson/followers","following_url":"https://api.github.com/users/martenson/following{/other_user}","gists_url":"https://api.github.com/users/martenson/gists{/gist_id}","starred_url":"https://api.github.com/users/martenson/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/martenson/subscriptions","organizations_url":"https://api.github.com/users/martenson/orgs","repos_url":"https://api.github.com/users/martenson/repos","events_url":"https://api.github.com/users/martenson/events{/privacy}","received_events_url":"https://api.github.com/users/martenson/received_events","type":"User","site_admin":false},"labels":[{"id":241204064,"node_id":"MDU6TGFiZWwyNDEyMDQwNjQ=","url":"https://api.github.com/repos/galaxyproject/galaxy/labels/area/UI-UX","name":"area/UI-UX","color":"006b75","default":false,"description":null},{"id":241207704,"node_id":"MDU6TGFiZWwyNDEyMDc3MDQ=","url":"https://api.github.com/repos/galaxyprojec ...

# %% [markdown]
# ### 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#
# * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %%
facts = requests.get('https://cat-fact.herokuapp.com/facts')
obj = json.loads(facts.text)
# 這是一個object，回傳資料型態為dict。
if type(obj == 'dict'):
    print(type(obj))
else:
    print("Not a dict type!")

# 取得欲parse的內容
contents = obj['all']
for content in contents:
    _id = content['_id']
    # 防止無'user'這個key值而產生錯誤
    if content.get('user') != None:
        userName = content['user']['name']
        print(userName)
# Out:
# <class 'dict'>
# {'first': 'Kasimir', 'last': 'Schulz'}
# {'first': 'Kasimir', 'last': 'Schulz'}
# {'first': 'Kasimir', 'last': 'Schulz'}
# {'first': 'Kasimir', 'last': 'Schulz'}
# {'first': 'Kasimir', 'last': 'Schulz'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Kasimir', 'last': 'Schulz'}
# {'first': 'Kasimir', 'last': 'Schulz'}
# {'first': 'Kasimir', 'last': 'Schulz'}
# {'first': 'Kasimir', 'last': 'Schulz'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Kasimir', 'last': 'Schulz'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Jackson', 'last': 'Sippe'}
# {'first': 'Kasimir', 'last': 'Schulz'}
# {'first': 'Kasimir', 'last': 'Schulz'}
# {'first': 'Hampton', 'last': 'McGrath'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Simon'}
# {'first': 'Kasimir', 'last': 'Schulz'}
# {'first': 'Kasimir', 'last': 'Schulz'}
# {'first': 'Kasimir', 'last': 'Schulz'}
# {'first': 'Kasimir', 'last': 'Schulz'}
# {'first': 'Kasimir', 'last': 'Schulz'}
# {'first': 'Kasimir', 'last': 'Schulz'}
# {'first': 'Kasimir', 'last': 'Schulz'}
# {'first': 'Kasimir', 'last': 'Schulz'}
# {'first': 'Kasimir', 'last': 'Schulz'}
# {'first': 'Kasimir', 'last': 'Schulz'}
# {'first': 'Kasimir', 'last': 'Schulz'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Kasimir', 'last': 'Schulz'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Kasimir', 'last': 'Schulz'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Kenny', 'last': 'Corsig'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'David', 'last': 'Gippner'}
# {'first': 'Beth', 'last': 'Rothwell'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Hedvig', 'last': 'Annersten'}
# {'first': 'Hedvig', 'last': 'Annersten'}
# {'first': 'Tests', 'last': 'HiQ'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Chloe', 'last': 'Simmons'}
# {'first': 'Shay', 'last': 'Zhang'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Veronika', 'last': 'Koval'}
# {'first': 'Erick', 'last': 'Vazquez'}
# {'first': 'Mateusz', 'last': 'Głowacki'}
# {'first': 'mohammed', 'last': 'aljundi'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Alex', 'last': 'Wohlbruck'}
# {'first': 'Daniel', 'last': 'Carvalho'}
# {'first': 'Leonard', 'last': 'Wohlfarth'}
# {'first': 'Thanadols', 'last': 'Supho'}
# {'first': 'Thanadols', 'last': 'Supho'}
# {'first': 'Wolfgang', 'last': 'Gruel'}
