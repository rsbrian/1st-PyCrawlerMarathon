# %% [markdown]
# # HTTP 動態網頁架構說明
#
#
# * 了解動態網頁的資料爬蟲策略
# * 知道非同步網頁載入機制（Ajax）
# * 學習兩種對應動態網頁爬蟲的的策略

# %% [markdown]
# ## 作業目標
#
# 回答以下問題：
#
# 1. 動態網頁跟靜態網頁的差別是什麼？原本靜態網頁的做法會產生什麼問題或是缺點？
# 2. 還記得我們在 ETTODAY 靜態爬蟲實作練習中，有請大家完成一個題目「取出今天所有的發文」，但仔細看其實並沒有真的把當天所有的新聞都抓回來， 試著回答看看原因是什麼？及該如何檢查？

# %% [markdown]
# ### 1. 動態網頁跟靜態網頁的差別是什麼？原本靜態網頁的做法會產生什麼問題或是缺點？

# %%
'''
動態網頁是透過AJAX的技術完成後續資料的傳遞。採用原本HTTP一來一回的方式呼叫是無法取得內容的。目前已知可透過兩種方法來取得內容。
1. 「模擬使用者開瀏覽器」
2. 「模擬JavaScript呼叫Data API，取得內容」
'''
# Out:
# '\n動態網頁是透過AJAX的技術完成後續資料的傳遞。採用原本HTTP一來一回的方式呼叫是無法取得內容的。目前已知可透過兩種方法來取得內容。\n1. 「模擬使用者開瀏覽器」\n2. 「模擬JavaScript呼叫Data API，取得內容」\n'

# %% [markdown]
# ### 2. 還記得我們在 ETTODAY 靜態爬蟲實作練習中，有請大家完成一個題目「取出今天所有的發文」，但仔細看其實並沒有真的把當天所有的新聞都抓回來， 試著回答看看原因是什麼？及該如何檢查？

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.ettoday.net/news/news-list.htm'
resp = requests.get(url)
resp.encoding = 'utf-8'
soup = BeautifulSoup(resp.text,'lxml')
news_list = soup.find('div', attrs={'class':'part_list_2'})
news = news_list.find_all('h3')
for item in news:
    print(item.span.text)
    print(item.em.text)
    print(item.a.text)

'''
透過http request只能取得一部分的資料。
透過Chrome browser開啟開發者工具(F12)，切換到「XHR」的頁籤，可以看到[show_roll.php]。
看來是以show_roll.php做為AJAX的動態呼叫，相關參數為：
1. offset
2. tPage
3. tFile
4. tOt
5. tSi
6. tAr
'''
# Out:
# 2019/12/30 15:03
# 社會
# 被爸爸趕出家門！他七年後發現自己「已死」　怒奔法院：我要復活
# 2019/12/30 15:00
# 體育
# 企聯射箭／寒舍演逆轉秀摘元年冠軍　明年再提升仿日職賽制
# 2019/12/30 15:00
# 影劇
# 27歲女星和未婚夫去探病「卻遭醉漢刺死」！　殺人犯2年後「被執行死刑」還公道
# 2019/12/30 15:00
# 旅遊
# 炸排骨入味不油膩！花蓮40年便當老店　主餐可挑4配菜超豐盛
# 2019/12/30 14:56
# 影劇
# 快訊／IZ*ONE、X1確定復活重啟活動！CJ聲明：會拋棄所有收益
# 2019/12/30 14:53
# 大陸
# 「基因編輯嬰兒」判決出爐！賀建奎入監3年　罰金超千萬
# 2019/12/30 14:53
# 財經
# Smart智富／勇敢面對自己的財務困境吧！
# 2019/12/30 14:52
# 政治
# 韓國瑜辯論會轟媒體　黃國昌：有失總統候選人的格局
# 2019/12/30 14:50
# 影劇
# 35歲沒做過體檢！　Apple出外景「撞到尾椎」…恐怖下場讓她轉念
# 2019/12/30 14:49
# 體育
# 新北U18／林岳谷生涯首支再見安打　凝重氛圍壓過喜悅
# 2019/12/30 14:48
# 論壇
# 尤里安／空運能力提升，國軍C-130H運輸機升級計劃
# 2019/12/30 14:48
# 直銷雲
# 東森社交電商擴張版圖！整合新商模「錢進中國」助優質台灣貨打入市場
# 2019/12/30 14:45
# 社會
# 底褲照塞滿手機...「偷拍慣犯」再現北捷西門站！對短裙妹「狂攝」
# 2019/12/30 14:44
# 大陸
# 基因編輯嬰兒案宣判！賀建奎遭判3年　法院：逾越道德底線
# 2019/12/30 14:40
# 財經
# 推廣Mini LED背光高階電視　大廠積極開發「主動式驅動技術」
# 2019/12/30 14:39
# 地方
# 守護南臺灣森林的驚奇4超人　重磅進駐屏東林管處
# 2019/12/30 14:37
# 健康
# 投資數十億合約「竹科主管失眠一個月」　醫：小心腦萎縮
# 2019/12/30 14:37
# ET車雲
# ...
